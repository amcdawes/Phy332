# %%
from sympy import sin, cos, I, E, plot, pi
# %matplotlib inline

# %%
from sympy.abc import x,y,z,t

# %%
plot(4*cos(1*t + 0.3))

# %% [markdown]
# We'll make some interactive graphs using a nice feature of the notebooks called "interact"
#
# More information here:
# https://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def makeplot(A,w,phi):
    plot(A*cos(w*t + phi),ylim=[-5,5])

# %%
interact(makeplot,A=2,w=(1,10),phi=1)
# Out:
# interactive(children=(IntSlider(value=2, description='A', max=6, min=-2), IntSlider(value=5, description='w', …
# <function __main__.makeplot(A, w, phi)>

# %% [markdown]
# Revise this command to set a range for each parameter: i.e. instead of A=2, use A=(1,5) to let A be a slider from 1 to 5. Some parameters may make the plot stop working... try to think about why that happens, and set a range to avoid them.
